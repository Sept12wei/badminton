# %%
import requests
headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36 Edg/122.0.0.0'
}
url = 'https://www.badmintoncn.com/ranking.php'
response = requests.get(url=url,headers=headers)
page_text = response.text

# %%
import csv
from lxml import etree
tree = etree.HTML(page_text)
tree.xpath('//tbody/tr/td[1]/text()')

rank_list = tree.xpath('//tr/td[1]/text()')[11:]
name_list = tree.xpath('//td/div/a/span/text()')
game_list = tree.xpath('//td[5]/text()')[3:]
game_list = [game.strip() for game in game_list]
score_list = tree.xpath('//td[6]/text()')[4:]


# 使用zip函数将两个列表拼接在一起
player_list = list(zip(rank_list, name_list,game_list,score_list))

# 打印拼接后的列表
for player in player_list:
    print(player)
# 写入CSV文件
with open('player_data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Rank', 'Name', 'Game', 'Score'])  # 写入标题行
    for player in player_list:
        writer.writerow(player)
# Out:
# ('1', '安赛龙', '14', '98715')
# ('2', '石宇奇', '19', '90984')
# ('3', '安东尼·西尼苏卡·金廷', '20', '85101')
# ('4', '安德斯·安东森', '20', '83594')
# ('5', '乔纳坦·克里斯蒂', '19', '81531')
# ('6', '奈良冈功大', '21', '81015')
# ('7', '李诗沣', '21', '77998')
# ('8', '昆拉武特·威提讪', '20', '77948')
# ('9', '普兰诺伊·哈塞纳·苏尼尔·库马尔', '20', '77647')
# ('10', '李梓嘉', '24', '68296')
# ('11', '骆建佑', '23', '67952')
# ('12', '西本拳太', '28', '67182')
# ('13', '拉克什亚·森', '22', '64021')
# ('14', '李卓耀', '27', '63499')
# ('15', '周天成', '30', '62398')
# ('16', '陆光祖', '21', '60771')
# ('17', '翁泓阳', '21', '59950')
# ('18', '黄智勇', '20', '58735')
# ('19', '林俊易', '30', '57286')
# ('20', '常山干太', '23', '56981')
# ('21', '克里斯托·波波夫', '24', '55656')
# ('22', '渡边航贵', '18', '54581')
# ('23', '杨灿', '26', '53273')
# ('24', '王子维', '29', '51410')
# ('25', '托马·朱尼尔·波波夫', '24', '51013')
# ('26', '伍家朗', '26', '49856')
# ('27', '斯里坎特', '25', '49723')
# ('28', '拉斯穆斯·格姆克', '18', '48029')
# ('29', '兹科·奥拉德维·瓦多约', '17', '46429')
# ('30', '苏力扬', '24', '44480')
# ('31', '大林拓真', '15', '43479')
# ('32', '普里耶修·拉贾瓦特', '18', '41810')
# ('33', '雷兰曦', '13', '41526')
# ('34', '马格纳斯·约翰森', '23', '40760')
# ('35', '李佳豪', '28', '40138')
# ('36', '基兰·乔治', '21', '39880')
# ('37', '梁峻豪', '18', '37991')
# ('38', '戚又仁', '21', '37616')
# ('39', '凯文·科登', '16', '35776')
# ('40', '赵俊鹏', '12', '35660')
# ('41', '阮日', '20', '34997')
# ('42', '王高伦', '28', '34654')
# ('43', '朱利安·卡拉吉', '19', '34568')
# ('44', '阿诺·梅克尔', '20', '34305')
# ('45', '伊戈尔·科埃略·德奥利维拉', '21', '34202')
# ('46', '萨西什·库马尔·卡鲁纳卡兰', '22', '34010')
# ('47', '马克·卡尔乔', '20', '33662')
# ('48', '亚历克斯·拉尼尔', '12', '33540')
# ('49', '全奕陈', '21', '33359')
# ('50', '田中涌士', '12', '32960')
# ('51', '米沙·西尔伯曼', '18', '32513')
# ('52', '桃田贤斗', '10', '32467')
# ('53', '简·劳达', '20', '31410')
# ('54', '乌里尔·弗朗西斯科', '16', '31059')
# ('55', '玛兹·克里斯托弗森', '18', '30793')
# ('56', '郑加恒', '19', '30168')
# ('57', '乔纳森·马蒂耶斯', '20', '29307')
# ('58', '阿尔维·法汉', '13', '29125')
# ('59', '卡尔·科尔约宁', '17', '29121')
# ('60', '黄郁岂', '20', '28800')
# ('61', '高桥洸士', '12', '28600')
# ('62', '詹俊为', '18', '27930')
# ('63', '阿德·雷斯基·德维卡约', '22', '27149')
# ('64', '米森·曼朱纳特', '18', '26030')
# ('65', '巴勃罗·阿比扬', '26', '25982')
# ('66', '乔金·奥尔多夫', '25', '24834')
# ('67', '阿尤什·谢蒂', '12', '24620')
# ('68', '德米特里·帕纳林', '25', '24475')
# ('69', '萨米尔·维尔马', '11', '24310')
# ('70', '桑卡尔·穆图萨米·苏布拉马尼安', '22', '24180')
# ('71', '乔瓦尼·托蒂', '24', '24058')
# ('72', '王柏崴', '13', '23290')
# ('73', '丹尼洛·博斯尼乌克', '19', '23204')
# ('74', '维伦·内塔辛格', '21', '23200')
# ('75', '路易斯·拉蒙·加里多', '16', '22799')
# ('76', '舒之颢', '27', '22772')
# ('77', '宋俊伟', '17', '22700')
# ('78', '廖倬甫', '18', '22363')
# ('79', '黎德发', '20', '22350')
# ('80', '舍沙·海仁·雷斯塔维托', '9', '21910')
# ('81', '凯·谢弗', '28', '21571')
# ('82', '卢卡斯·克莱伯特', '12', '21526')
# ('83', '梅拉巴鲁旺', '21', '21303')
# ('84', '阮海当', '22', '21200')
# ('85', '达尼尔·杜博文科', '14', '21180')
# ('86', '法比安·罗斯', '22', '20977')
# ('87', '法比奥·卡波尼奥', '23', '20313')
# ('88', '秦野陆', '13', '20090')
# ('89', '郭冠麟', '19', '19790')
# ('90', '陈延泽', '11', '19539')
# ('91', '马库斯·巴思', '26', '19352')
# ('92', '吴英伦', '12', '19167')
# ('93', '柯林斯·瓦伦丁·菲利蒙', '17', '19050')
# ('94', '路易斯', '22', '18996')
# ('95', '马克·雪莱·阿尔卡拉', '20', '18970')
# ('96', '阿努奥卢瓦波·朱翁·奥佩约里', '14', '18848')
# ('97', '黄涵瑞', '19', '18525')
# ('98', '约翰斯·索特·马塞利诺', '8', '18513')
# ('99', '维克多·赖', '12', '18357')
# ('100', '马克斯·卫斯基兴', '21', '18289')

# %%
import re
sid_list = tree.xpath('//div[@class="player"]//a/@href')
# 使用正则表达式提取数字并替换原始列表中的链接
for i, link in enumerate(sid_list):
    match = re.search(r'\d+', link)  # 匹配数字部分
    if match:
        extracted_id = match.group()  # 获取匹配的数字
        sid_list[i] = extracted_id
sid_list
# Out:
# ['562',
#  '1256',
#  '1268',
#  '1515',
#  '1374',
#  '1546',
#  '1732',
#  '1555',
#  '915',
#  '1523',
#  '1730',
#  '1446',
#  '1463',
#  '1329',
#  '600',
#  '1724',
#  '1736',
#  '1697',
#  '1745',
#  '1327',
#  '1766',
#  '1441',
#  '1755',
#  '1136',
#  '1757',
#  '675',
#  '628',
#  '1720',
#  '1522',
#  '2862',
#  '1972',
#  '2157',
#  '1518',
#  '2233',
#  '1460',
#  '2037',
#  '1535',
#  '2103',
#  '1454',
#  '1182',
#  '1759',
#  '1524',
#  '2348',
#  '2114',
#  '1631',
#  '3082',
#  '1733',
#  '2235',
#  '2484',
#  '3951',
#  '1750',
#  '595',
#  '2225',
#  '2424',
#  '2090',
#  '2125',
#  '2673',
#  '3314',
#  '1769',
#  '4676',
#  '2165',
#  '1359',
#  '1763',
#  '2156',
#  '1201',
#  '3981',
#  '3166',
#  '2587',
#  '664',
#  '2349',
#  '2502',
#  '5640',
#  '2171',
#  '3928',
#  '4113',
#  '2004',
#  '977',
#  '2748',
#  '2888',
#  '1656',
#  '1762',
#  '1765',
#  '2885',
#  '2887',
#  '9241',
#  '1573',
#  '2230',
#  '2629',
#  '3128',
#  '2460',
#  '2540',
#  '2620',
#  '3977',
#  '1498',
#  '2993',
#  '1870',
#  '3729',
#  '2997',
#  '2707',
#  '1777']

# %%
base_url = 'https://www.badmintoncn.com/cbo_star/star_view_ability.php?sid='
for sid in sid_list:
    url_player = base_url + str(sid)
    response = requests.get(url=url_player,headers=headers)
    page_text_player = response.text
    tree = etree.HTML(page_text_player)
#     capacity_list = tree.xpath('//tr/td/span/text()')
#     capacity_list.append(tree.xpath('//div/span[1]/span')[0])
#     capacity_list
#      # 使用XPath表达式提取数据，如果匹配结果为空则跳过
#     value_list = tree.xpath('//div/span[1]/span')
#     if not value_list:
#         print("数据不存在，跳过处理")
#         continue
    
#     # 在此处进行对存在数据的处理
#     for value in value_list:
#         print(value.text)
#         # 处理每个容量数据
#         pass
# Out:
# 4.7
# 4.5
# 4.4
# 4.2
# 4.3
# 4.3
# 4.3
# 4.5
# 4.4
# 4.3
# 4.5
# 4.1
# 4.4
# 4.2
# 4.4
# 4
# 4.3
# 4.1
# 4.2
# 4
# 4.3
# 数据不存在，跳过处理
# 3.9
# 4
# 数据不存在，跳过处理
# 4
# 4.2
# 4.1
# 4.2
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 4
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 4.2
# 4.1
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 4.6
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理
# 数据不存在，跳过处理

# %%
base_url = 'https://www.badmintoncn.com/cbo_star/star_view_ability.php?sid='
for sid in sid_list:
    url_player = base_url + str(sid)
    response = requests.get(url=url_player,headers=headers)
    page_text_player = response.text
    tree = etree.HTML(page_text_player)
    capacity_list = tree.xpath('//tr/td/span/text()')
    capacity_list.append(tree.xpath('//div/span[1]/span')[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-29e0f7f511c0> in <module>()
#       6     tree = etree.HTML(page_text_player)
#       7     capacity_list = tree.xpath('//tr/td/span/text()')
# ----> 8     capacity_list.append(tree.xpath('//div/span[1]/span')[0])
#       9     capacity_list
#
# IndexError: list index out of range
